# %% [markdown]
# <a href="https://colab.research.google.com/github/Farizz026/c-fundamental-/blob/main/learn_1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# materi pertama pembelajaran tentang paython

# %%
a=5
b=10
c=a+b
print (c)
# Out:
# 15

# %% [markdown]
# # Bagian Baru
